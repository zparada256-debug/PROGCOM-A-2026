# %% [markdown]
# <a href="https://colab.research.google.com/github/zparada256-debug/PROGCOM-A-2026/blob/main/TALLER_EN_CLASE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TALLER

# %%
#EJERCICIO 1
Frutas = {
    "manzana": 2500,
    "pera": 1800,
    "uva": 3200
}
print(f'"manzana": {Frutas["manzana"]}')
print(f'"pera": {Frutas["pera"]}')
print(f'"uva": {Frutas["uva"]}')

# %%
#EJERCICIO 2
personajes = {
    "constructor": 15,
    "alcaldesa": 12,
    "ingeniero": 10
}

personajes["caroñero"] = 18

print("Personajes FUNPRO:", personajes)

# %%
#EJERCICIO 3
pociones = {
    "vida": 5,
    "Inteligencia": 3,
    "fuerza": 7
}

print("Pociones originales:", pociones)

pociones["vida"] = 10
print("Pociones actualizadas:", pociones)

# %%
#EJERCICIO 4
herramientas = {
    "Varita": "Madera de sauce",
    "Cristal": "Cuarzo rosa",
    "Amuleto": "Oro encantado",
    "Grimorio": "Cuero ancestral"
}

print("Herramientas originales:", herramientas)

del herramientas["Cristal"]

print("Herramientas finales:", herramientas)

# %%
#EJERCICIO 5
estudiantes = {
    "Jp": 85,
    "Simon": 92,
    "Cristian": 78,
    "Zharick": 95,
    "Sebastian ": 88
}

def promedio_todos():
    total = 0
    for nota in estudiantes.values():
        total = total + nota
    promedio = total / len(estudiantes)
    print("El promedio de todos los estudiantes es:", promedio)

def promedio_estudiante(nombre):
    if nombre in estudiantes:
        print("La nota de", nombre, "es:", estudiantes[nombre])
    else:
        print("El estudiante no existe en el diccionario.")

promedio_todos()
promedio_estudiante("Zharick")

# %%
#EJERCICIO 6
personajes_rpg = {
    "guerrero": {"nivel": 15, "arma": "espada"},
    "mago": {"nivel": 12, "arma": "bastón"},
    "arquero": {"nivel": 10, "arma": "arco"}
}

clave = "hechicero"

if clave in personajes_rpg:
    print(f" '{clave}' encontrado:", personajes_rpg[clave])
else:
    print(f" Advertencia: La clave '{clave}' no existe en el diccionario.")

# %%
#EJERCICIO 7
palabra = "magia"
conteo = {}

for letra in palabra:
    if letra in conteo:
        conteo[letra] = conteo[letra] + 1
    else:
        conteo[letra] = 1

print("Conteo de letras en", palabra, ":")
for letra in conteo:
    print(letra, ":", conteo[letra])

# %%
#EJERCICIO 8
elementos = ["gema", "oro", "gema", "madera", "oro", "oro", "gema"]
conteo = {}

for elemento in elementos:
    if elemento in conteo:
        conteo[elemento] = conteo[elemento] + 1
    else:
        conteo[elemento] = 1

print("Elementos recolectados en la expedición:")
for elemento in conteo:
    print(elemento, ":", conteo[elemento])

# %%
#EJERCICIO 9

# %%
#EJERCICIO 10
inventario = {
    "manzana": 10,
    "pan": 4,
    "leche": 6
}

print("Inventario inicial:", inventario)


inventario["huevos"] = 12
print("\nDespués de agregar 'huevos':", inventario)


inventario["leche"] = 9
print("Después de actualizar 'leche' a 9:", inventario)

del inventario["pan"]
print("Después de eliminar 'pan':", inventario)

print("\nInventario final:")
for objeto in inventario:
    print(" -", objeto, ":", inventario[objeto])
