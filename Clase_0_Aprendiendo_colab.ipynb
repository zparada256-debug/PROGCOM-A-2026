# %% [markdown]
# <a href="https://colab.research.google.com/github/zparada256-debug/PROGCOM-A-2026/blob/main/Clase_0_Aprendiendo_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bienvenida

# %% [markdown]
# ##Aprendiendo a usar print
# print() es un metodo que permite imprimir informacion en consola
#
# sintaxis
#
#
# ```
# if (condicion)== verdadera
#   print ("pasan cositas")
# else:
#   print("pasan otras cositas")
#
# ```
#  El print() puede imprimir lo siguiente
#
#
# 1.   Cualquier tipo de dato
# 2.   Cualquier metodo o funcion (su direcccion en memoria)
# 3.   Concatenacion de texto
# 4.   Operaciones matematicas

# %% [markdown]
# ###Concatenacion
# Concatenar es unir dos tipos diferentes de datos

# %% [markdown]
# ##conociendo el input
# input() es un metodo con triple funcion
#
#
# *   Declara: toda la informacion que ingresa con este metodo, se declara automaticamente como string (caracter).
# *   lee: porque almacena en una variable
# *   imprime:porque lo que esta entre los parentisis, se visualiza en consola

# %%
 x=int(input("ingrese su edad:"))
 y=input("ingrese su nombre")
 #Ejemplo1
print(y,"tiene una edad de", x)

# %%
#Ejemplo 2
print(y+" tiene una edad de "+str(x))

# %%
#Ejemplo3
print(F"{y} tiene una edad de {x}")
